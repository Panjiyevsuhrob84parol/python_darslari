# %%
from email import header
from wsgiref import headers
import requests
from bs4 import BeautifulSoup
import time

url = "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541"

headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36",
    "Referer":"https://www.google.com/",
    "Accept-Language":"ru,en-US;q=0.9,en;q=0.8,uz;q=0.7",
}

start_time =time.time()
response =requests.get(url, headers=headers, timeout=10)
end_time=time.time()

total_time=end_time-start_time
print(f"time taken: {total_time}")
print(response.status_code)

soup = BeautifulSoup(response.text, "lxml")

title=soup.title.text
print(title)
# Out:
# time taken: 1.4125792980194092
# 200
# Qarshi, Qashqadaryo, O‘zbekiston Kunlik ob-havo | AccuWeather

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="accuweather" lang="uz">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <link href="https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541" rel="canonical"/>
# <title>Qarshi, Qashqadaryo, O‘zbekiston Kunlik ob-havo | AccuWeather</title>
# <meta content="Know what's coming with AccuWeather's extended daily forecasts for Qarshi, Qashqadaryo, O‘zbekiston. Up to 90 days of daily highs, lows, and precipitation chances." name="Description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="origin" name="referrer"/>
# <meta content="AccuWeather" property="fb:profile_id"/>
# <meta content="132437483467956" property="fb:app_id"/>
# <meta content="71781612888" property="fb:pages"/>
# <meta content="website" property="og:type"/>
# <meta content="Qarshi, Qashqadaryo, O‘zbekiston Kunlik ob-havo | AccuWeather" property="og:title"/>
# <meta content="Know what's coming with AccuWeather's extended daily forecasts for Qarshi, Qashqadaryo, O‘zbekiston. Up to 90 days of daily highs, lows, and precipitation chances." property="og:description"/>
# <meta content="AccuWeather" property="site_name"/>
# <meta content="https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541" property="og:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:url"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" property="og:image:secure_url"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Qarshi, Qashqadaryo, O‘zbekiston Kunlik ob-havo | AccuWeather" name="twitter:text:title"/>
# <meta content="Qarshi, Qashqadaryo, O‘zbekiston Kunlik ob-havo | AccuWeather" name="twitter:title"/>
# <meta content="Know what's coming with AccuWeather's extended daily forecasts for Qarshi, Qashqadaryo, O‘zbekiston. Up to 90 days of daily highs, lows, and precipitation chances." name="twitter:description"/>
# <meta content="https://twitter.com/accuweather" name="twitter:site:id"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator"/>
# <meta content="https://twitter.com/accuweather" name="twitter:creator:id"/>
# <meta content="https://www.accuweather.com/images/logos/aw-logo-og-meta.png" name="twitter:image"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:iphone"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:iphone"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:iphone"/>
# <meta content="AccuWeather: Weather Tracker" name="twitter:app:name:ipad"/>
# <meta content="U7D6TVQ9TT.com.yourcompany.TestWithCustomTabs" name="twitter:app:id:ipad"/>
# <meta content="https://apps.apple.com/US/app/id300048137?mt=8" name="twitter:app:url:ipad"/>
# <meta content="AccuWeather Winter weather alerts &amp; forecast radar" name="twitter:app:name:googleplay"/>
# <meta content="com.accuweather.android" name="twitter:app:id:googleplay"/>
# <meta content="https://play.google.com/store/apps/details?id=com.accuweather.android" name="twitter:app:url:googleplay"/>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "Organization",
# 	"name": "AccuWeather",
# 	"url": "https://www.accuweather.com",
# 	"sameAs": [
# 		"https://www.facebook.com/AccuWeather",
# 		"https://twitter.com/BreakingWeather",
# 		"https://www.instagram.com/accuweather",
# 		"https://www.youtube.com/user/accuweather"
#   ]
# }
# </script>
# <script type="application/ld+json">
# 	{
# 		"@context": "https://schema.org",
# 		"@type": "Place",
# 		"address": {
# 			"@type": "PostalAddress",
# 			"addressLocality": "Qarshi, O&#x2018;zbekiston",
# 			"addressRegion": "Qashqadaryo",
# 			"postalCode": ""
# 		},
# 		"geo": {
# 			"@type": "GeoCoordinates",
# 			"latitude": "38.883",
# 			"longitude": "65.8",
# 			"addressCountry": "UZ",
# 			"postalCode": ""
# 		},
# 		"name": "Qarshi, Qashqadaryo, O&#x2018;zbekiston"
# 	}
# 	</script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org",
# 	"@type": "WebSite",
# 	"mainEntityOfPage": {
# 		"@type": "WebPage",
# 		"@id": "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541",
# 		"relatedLink": "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541"
# 	},
# 	"image": {
# 		"@type": "ImageObject",
# 		"url": "https://www.accuweather.com/images/logos/accuweather-dark.png",
# 		"height": 172,
# 		"width": 1200
# 	},
# 	"author": {
# 		"@type": "Person",
# 		"name": "AccuWeather"
# 	},
# 	"publisher": {
# 		"@context": "https://schema.org",
# 		"@type": "Organization",
# 		"name": "AccuWeather",
# 		"url": "https://www.accuweather.com/",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://www.accuweather.com/images/logos/accuweather-dark-small.png",
# 			"width": 163,
# 			"height": 23
# 		}
# 	},
# 	"url": "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541",
# 	"headline": "Qarshi, Qashqadaryo, O&#x2018;zbekiston Kunlik ob-havo",
# 	"description": "Know what&#x27;s coming with AccuWeather&#x27;s extended daily forecasts for Qarshi, Qashqadaryo, O&#x2018;zbekiston. Up to 90 days of daily highs, lows, and precipitation chances."
# }
# </script>
# <script>window.tagEngineDataLayer = {} ?? {};</script>
# <style>
# 		@font-face {
# 			font-family: 'Solis';
# 			src: url('/fonts/Solis-Regular.woff2') format('woff2');
# 			font-weight: 400;
# 			font-style: normal;
# 			font-display: swap;
# 		}
# 	</style>
# <style>
# 		:root {
# 			--bg: #1f1f1f;
# 			--header-bg: #1f1f1f;
# 			--header-bg-top: #1f1f1f;
# 		}
# 	</style>
# <script>
# 		window.tagEngineDataLayer = window.tagEngineDataLayer || {};
# 		window.tagEngineDataLayer.ketch = {
# 			isEnabled: true,
# 		};
# 	</script>
# <script>
# 	window.pushlyTranslations = {"en":{"phrase":"Get AccuWeather alerts as they happen with our browser notifications.","enableNotifications":"Enable Notifications","noThanks":"No, Thanks","enabled":"Notifications Enabled","thanks":"Thanks! We'll keep you informed."},"es":{"phrase":"Recibe alertas de AccuWeather en su navegador en el momento","enableNotifications":"Habilitar Notificaciones","noThanks":"No, Gracias","enabled":"Notificaciones Habilitadas","thanks":"¡Gracias! Te mantendremos al tanto."}};
# </script>
# <script>(async () => {function h(i){return`[${i}]
# `}function I(i,e){if(!i&&(!e||Array.isArray(e)&&e.length===0))return;const t=[];return i&&t.push(i),e&&(Array.isArray(e)?t.push(...e):t.push(e)),t}class D{timeouts=new Map;setTimeout(e,t,a){this.clearTimeout(e);const n=setTimeout(()=>{t(),this.clearTimeout(e)},a);this.timeouts.set(e,n)}clearTimeout(e){const t=this.timeouts.get(e);t&&(clearTimeout(t),this.timeouts.delete(e))}}const R=window.awxTimeoutProcessor??new D;window.awxTimeoutProcessor=R;function S(i){if(i<=5e3){if(i%500===0)return 500;if(i%1e3===0)return 1e3}return Math.floor(i/2)}function M(i,e,{callerScope:t,logger:a}={}){const n=Date.now();return new Promise(s=>{let r=e();const o=()=>{const m=Date.now()-n,A=[t??"","isReadyPromise"].filter(Boolean).join("::");return window.debugDataLayer?.enabled&&(a?a("debug",{scope:A,message:`Ready in ${m}ms`}):console.debug(h("isReadyPromise"),`Ready in ${m}ms`)),s(r)};if(r)return o();window.awxLogger?.withScope(`${t}::isReadyPromise`).debug("Waiting for isReadyChecker to return true");let g,d;const v=()=>{clearInterval(d),clearTimeout(g),g=void 0,d=void 0};d=setInterval(()=>{if(r=e(),r)return v(),o()},S(i)),g=setTimeout(()=>(v(),o()),i)})}const k={type:"application/json"},E=5e3,T={pageLeave:6e5,timers:3e4},C={timers:"timers",pageView:"pageview",pageLeave:"pageleave",genericEvents:"events",updateProfile:"update-profile"},$={1:["pageView","pageLeave"],2:["pageView","pageLeave","updateProfile","genericEvents"]},N={ads:"adInfo",bot:"isBot",page:"pageInfo",user:"userInfo",test:"testGroup",session:"sessionInfo",version:"platformVersion"},l=()=>!!window.adInfo?.userid3p&&!!window.adInfo?.userid;function O(i){return!!i?.pageView?.ads?.code&&l()}function j(i){return!!i?.pageView?.adInfo?.code&&l()}function p(i){return Array.isArray(window.tagEngineDataLayer?.raine?.enabledVersions)?i===void 0?window.tagEngineDataLayer.raine.enabledVersions.length>0:window.tagEngineDataLayer.raine.enabledVersions.includes(i):!1}function u(i,e){return e??=c()?.[i],p(i)&&!!e}function z(i,e){e??=c()?.[i];const t=()=>i===1?O(e):j(e);return p(i)&&u(i,e)&&t()}function L(i,e){return e?Object[i===1?"keys":"values"](N).every(n=>n in e):!1}function y(i,e=!0){return e?z(i):u(i)}async function B(i,e=5e3){return M(e,()=>y(i),{callerScope:"isRaineReadyAsync"})}const w={isReady:y,isEnabled:p,isAvailable:u,isDataValid:L,isReadyAsync:B};function c(){return{1:window.tagEngineDataLayer?.raine?.raineV1,2:window.tagEngineDataLayer?.raine?.raineV2}}function b(){return{eventsState:c(),eventsMap:$}}class G{pageIndex=0;version;events;isAdsSetupComplete=l();isInitialized=!1;maxInitializeDelay=E;debug=!1;isSPA=!1;timeoutDurations;logger=void 0;constructor(e,t){this.version=e,this.events=t??["pageview","pageleave"],this.isSPA=!!window.tagEngineDataLayer.isSPA;const a=window.tagEngineDataLayer.raine;this.debug=!!window.debugDataLayer?.enabled,this.maxInitializeDelay=a?.initializeDelay||E,this.timeoutDurations={...T,...a?.timeoutDurations}}isReady(){return this.isInitialized}getLogger(e){return this.logger??=window.awxLogger?.withScope("Analytics"),e?this.logger?.withScope(e):this.logger}setIsAdsSetupComplete(e){this.log("debug",{scope:"setIsAdsSetupComplete",message:`RaineV${this.version} ads setup complete...`,args:{instance:this}}),this.isAdsSetupComplete=e}setIsInitialized(e){this.log("debug",{scope:"setIsInitialized",message:`RaineV${this.version} is initialized...`,args:{instance:this}}),this.isInitialized=e}getRaineHost(){const e=`raineV${this.version}Host`;let t;if(window.tagEngineDataLayer.raine&&e in window.tagEngineDataLayer.raine&&window.tagEngineDataLayer.raine[e]&&(t=window.tagEngineDataLayer.raine[e]),!t){this.log("error",{scope:"getRaineHost",message:`RaineV${this.version} host not found in data layer`});return}return t}sendAnalyticsEventData(e,t,a){const n={hostUrl:e,event:t,data:a};this.log("debug",{scope:`sendAnalyticsEventData::${t}`,message:"Sending analytics event data.",args:n}),window.debugDataLayer?.analytics?.raine?.requestService==="fetch"?fetch(e,{method:"PO ...
# `,...g)};updateRaineConstants(e){if(!window.tagEngineDataLayer.raine){this.log("error",{scope:"updateRaineConstants",message:"RAINE object not found in data layer."});return}window.tagEngineDataLayer.raine?.constants||(window.tagEngineDataLayer.raine.constants=b()),window.tagEngineDataLayer.raine.constants={...window.tagEngineDataLayer.raine.constants,eventsState:{...window.tagEngineDataLayer.raine.constants.eventsState,[this.version]:{...window.tagEngineDataLayer.raine.constants.eventsState[this.version],...e}}}}}class H extends V{constructor(){super(1,["pageview","pageleave"],window.tagEngineDataLayer.raine.raineV1.pageView),this.initEventListeners()}getPageGroup(){return this.setPageGroup(window.tagEngineDataLayer.pageGroup)}setPageViewAdInfo(){const e="adInfo"in window?window.adInfo:{},t=this.pageView??{};t.ads.status="userid"in e?e.userid:"",t.ads.cookie3p="userid3p"in e?e.userid3p:"",window.tagEngineDataLayer.raine.raineV1.pageView=t}refreshRaineData(){if(window.tagEngineDataLayer.raine)return this.pageLeave=this.createPageLeaveEvent(),this.updateRaineConstants({pageView:this.pageView,pageLeave:this.pageLeave}),window.tagEngineDataLayer.raine}updatePageView(){this.pageView=this.createPageViewEvent(window.tagEngineDataLayer.raine?.raineV1?.pageView),window.tagEngineDataLayer.raine?.raineV1&&(window.tagEngineDataLayer.raine.raineV1.pageView=this.pageView)}createPageViewEvent(e){const t=e??this.pageView??{};return this.setPageViewAdInfo(),{...t,page:{...t.page,group:this.getPageGroup()},user:{...t.user,offset:this.getUserOffset()}}}sendPageViewEvent(){window.tagEngineDataLayer.raine?.raineV1Host?(this.sendAnalyticsEventData(`${window.tagEngineDataLayer.raine.raineV1Host}/rainev1/p`,"pageview",this.pageView),this.log("debug",{scope:"sendPageViewEvent",message:"Event pageview successfully sent.",args:{pageView:this.pageView,raineV1Events:window.tagEngineDataLayer.raine.raineV1}})):this.log("warning",{scope:"sendPageViewEvent",message:"Event pageview is undefined."})}createPageLeaveEvent(){const e=[],t=this.pageView?.id??window.tagEngineDataLayer.raine?.raineV1?.pageView?.id??"";return window.awxPerformance.iterateAwxPerformanceMarks(window.awxPerformance.getAwxPerformanceMarksByPageSession(this.pageIndex),(a,n)=>{this.pageIndex===a.detail.pageIndex&&e.push(n)}),e.push({name:"raine:timeOnPage",time:window.awxPerformance.getTimeOnPage(this.pageIndex)}),this.pageLeave={id:t,scroll:window.awxEventListenerProcessor.getScrollDepth(),timers:e},this.updateRaineConstants({pageLeave:this.pageLeave}),this.pageLeave}resetTimersOnPageChange(){this.resetPageLeaveEventTimeout()}sendPageLeaveEvent(e=!1){(e||this.isSPA||document.visibilityState==="hidden")&&!this.pageLeaveFired&&window.tagEngineDataLayer.raine?.raineV1Host&&(this.pageView&&this.createPageLeaveEvent()?(this.sendAnalyticsEventData(`${window.tagEngineDataLayer.raine.raineV1Host}/rainev1/leavepage`,"pageleave",this.pageLeave),this.pageLeaveFired=!0,this.log("debug",{scope:"sendPageLeaveEvent",message:"Event pageleave successfully sent.",args:{pageLeave:this.pageLeave}})):this.log("warning",{scope:"sendPageLeaveEvent",message:"Unable to sent pageleave event. Check the args to ensure they are valid.",args:{force:e,isSPA:this.isSPA,documentVisibilityState:document.visibilityState,isPageLeaveSent:this.pageLeaveFired,pageView:this.pageView,pageLeave:this.pageLeave}}))}}class U extends V{updateProfile;genericEvents={id:"",time:"",events:[]};timersEvent;constructor(){super(2,Object.values(C).map(e=>e),window.tagEngineDataLayer.raine.raineV2.pageView),this.updateProfile=window.tagEngineDataLayer.raine?.raineV2?.updateProfile,this.updateProfile&&(this.updateProfile.user={...this.updateProfile.user,...this.pageView?.userInfo||{},offset:this.getUserOffset()},this.sendUpdateProfileEvent()),this.initEventListeners(),window.addEventListener("onUpdateProfile",this.onUpdateProfile.bind(this)),this.resetTimersEventTimeout(),this.initGenericEvents(),window.trackRaineEvent=this.trackRaineEvent.bind ...
# //# sourceMappingURL=raine.inline-e6956cc3.js.map
# })();</script><script>
#     if (window.tagEngineDataLayer?.ketch?.isEnabled !== false) {
#       // https://cdn.ketchjs.com/plugins/v1/tcf/stub.js
#       window.__gpp_addFrame=function(e){if(!window.frames[e])if(document.body){var t=document.createElement("iframe");t.style.cssText="display:none",t.name=e,document.body.appendChild(t)}else window.setTimeout(window.__gpp_addFrame,10,e)},window.__gpp_stub=function(){var e=arguments;if(__gpp.queue=__gpp.queue||[],__gpp.events=__gpp.events||[],!e.length||1==e.length&&"queue"==e[0])return __gpp.queue;if(1==e.length&&"events"==e[0])return __gpp.events;var t=e[0],p=e.length>1?e[1]:null,n=e.length>2?e[2]:null;const a=localStorage.getItem("_ketch_gpp_v1_");let s=null;if(a&&(s=JSON.parse(window.atob(a))),"ping"===t)p(s||{gppVersion:"1.1",cmpStatus:"stub",cmpDisplayStatus:"hidden",signalStatus:"not ready",sectionList:[],applicableSections:[],gppString:"",parsedSections:{}},!0);else if("addEventListener"===t){"lastId"in __gpp||(__gpp.lastId=0),__gpp.lastId++;var i=__gpp.lastId;__gpp.events.push({id:i,callback:p,parameter:n}),p({eventName:"listenerRegistered",listenerId:i,data:!0,pingData:s||{gppVersion:"1.1",cmpStatus:"stub",cmpDisplayStatus:"hidden",signalStatus:"not ready",sectionList:[],applicableSections:[],gppString:"",parsedSections:{}}},!0)}else if("removeEventListener"===t){for(var _=!1,l=0;l<__gpp.events.length;l++)if(__gpp.events[l].id==n){__gpp.events.splice(l,1),_=!0;break}p({eventName:"listenerRemoved",listenerId:n,data:_,pingData:s||{gppVersion:"1.1",cmpStatus:"stub",cmpDisplayStatus:"hidden",signalStatus:"not ready",sectionList:[],applicableSections:[],gppString:"",parsedSections:{}}},!0)}else"hasSection"===t?p(!1,!0):"getSection"===t||"getField"===t?p(null,!0):__gpp.queue.push([].slice.apply(e))},window.__gpp_msghandler=function(e){var t="string"==typeof e.data;try{var p=t?JSON.parse(e.data):e.data}catch(e){p=null}if("object"==typeof p&&null!==p&&"__gppCall"in p){var n=p.__gppCall;window.__gpp(n.command,(function(p,a){var s={__gppReturn:{returnValue:p,success:a,callId:n.callId}};e&&e.source&&e.source.postMessage&&e.source.postMessage(t?JSON.stringify(s):s,"*")}),"parameter"in n?n.parameter:null,"version"in n?n.version:"1.1")}},"__gpp"in window&&"function"==typeof window.__gpp||(window.__gpp=window.__gpp_stub,window.addEventListener("message",window.__gpp_msghandler,!1),window.__gpp_addFrame("__gppLocator"));
#
#       // https://cdn.ketchjs.com/plugins/v1/gpp/stub.js
#       !function(){const e=()=>{const e="__tcfapiLocator",t=[],n=window;let o,s,a=n;for(;a;){try{if(a.frames[e]){o=a;break}}catch(e){}if(a===n.top)break;a=a.parent}o||(!function t(){const o=n.document,s=!!n.frames[e];if(!s)if(o.body){const t=o.createElement("iframe");t.style.cssText="display:none",t.name=e,o.body.appendChild(t)}else setTimeout(t,5);return!s}(),n.__tcfapi=function(...e){if(!e.length)return t;if("setGdprApplies"===e[0])e.length>3&&2===parseInt(e[1],10)&&"boolean"==typeof e[3]&&(s=e[3],"function"==typeof e[2]&&e[2]("set",!0));else if("ping"===e[0]){const t=localStorage.getItem("_ketch_tcf_ping_v1_");t?"function"==typeof e[2]&&e[2](JSON.parse(window.atob(t))):"function"==typeof e[2]&&e[2]({gdprApplies:s,cmpLoaded:!1,cmpStatus:"stub"})}else if("addEventListener"===e[0]){const n=localStorage.getItem("_ketch_tcf_tcdata_v1_");n?"function"==typeof e[2]&&e[2](JSON.parse(window.atob(n)),!0):t.push(e)}else t.push(e)},n.addEventListener("message",(function(e){const t="string"==typeof e.data;let n={};if(t)try{n=JSON.parse(e.data)}catch(e){}else n=e.data;const o="object"==typeof n&&null!==n?n.__tcfapiCall:null;o&&window.__tcfapi(o.command,o.version,(function(n,s){let a={__tcfapiReturn:{returnValue:n,success:s,callId:o.callId}};e&&e.source&&e.source.postMessage&&e.source.postMessage(t?JSON.stringify(a):a,"*")}),o.parameter)}),!1))};"undefined"!=typeof module?module.exports=e:e()}();
#
#       // ketch boot script
#       (function () {
#         window.semaphore = window.semaphore || [];
#         window.ketch = function () {
#           window.semaphore.push(arguments);
#         };
#         var e = document.createElement("script");
#         e.type = "text/javascript";
#         e.src = "https://global.ketchcdn.com/web/v3/config/accuweather/website_smart_tag/boot.js";
#         e.defer = e.async = !0;
#         document.getElementsByTagName("head")[0].appendChild(e);
#       })();
#     }
# </script>
# <link href="https://www.accuweather.com/tags/shared/head/ketch-2d5abe96.css" rel="stylesheet"/>
# <script>
# 	 var globalAdConfig = {"prebidTimeout":500,"awxTimeout":750,"ortbSite":{"categories":["IAB7","IAB10","IAB15","IAB20","223","274","390","464","653"],"content":{"title":"","url":"","categories":["IAB15-10","390","657"],"productQuality":"1","context":"5","keywords":"","sourceRelationship":1,"language":"","data":{"name":"accuweather.com","extensions":{"segtax":"4"},"segments":[{"name":"id","value":"390"},{"name":"id","value":"657"}]}},"domain":"accuweather.com","keywords":"","name":"AccuWeather","privacyPolicy":1,"mobile":1,"pageCategories":["IAB15-10","390","657"],"publisher":{"name":"AccuWeather","domain":"accuweather.com","categories":["IAB7","IAB10","IAB15","IAB20","223","274","390","464","653"]},"sectionCategories":[""]},"enableSingleRequest":true,"lazyLoadingData":"{fetchMarginPercent:150,renderMarginPercent:75,mobileScaling:1.0}","skipGoogleAdManager":true,"prebidBundleId":"a","testVariant":"","disableInitialAdLoad":true,"javascriptHead":"","javascriptBody":""};
# 		 (['segtax']).forEach((key) => {if(globalAdConfig.ortbSite.content.data.extensions?.[key]){ globalAdConfig.ortbSite.content.data.extensions[key] = parseInt(globalAdConfig.ortbSite.content.data.extensions[key]) }})
# var isPrebidDisabled = true;
# var adExclusion = null;
# var botDetected = 1;
# var adInfo = {"fdate":"20260118","lang":"uz","ut":"1","advelvet":"1","bot":"1, Unknown Bot (DCDF55702DF6A948E951CDBF9EA3D01D):monitor:Browser Impersonator","pgview":"1","partner":"google_search_accuweather","ufdb":"UZ25","city":"Qarshi","country":"UZ","state":"QA","dma":null,"key":"350541","browser":"chrome","connection":"mobile_vhigh_5000","wx_seg":"102103100,102101100,100108101,101100100,102102100,102100100,108102100,102104102,101106102,101102102,100106105,101107101,108101100,104101101,100106104,107100100,108103102,101105101,107101100,100000100,101101100,100100,109101101,108104100,110100101,101104100,101108100,103100101,109105102,108100101,101103100,100113102,104100104,105100101,100109101,109100101,107103101,109106101,109102101,103101102,109103101,109104101,100114105,100109106","cuhd":"81","cuhi":"36","cuuv":"1","cuwd":"5","cuwx":"7","realfeel":"35,a40,b40,c45,d45","fc1hi":"40","fc1lo":"29","fc1wx":"7","lfscategory":"snow","lfsday":"5","lfsseverity":"4","lfs":"4_snow_5","pt":"0","userid":"active","userid3p":"active","iabctax":"IAB15-10,390,657","sub":"free"};
#
# // page views
# var awPageViewName = 'awx_pv';
# var pageViewItem = JSON.parse(window.localStorage.getItem(awPageViewName));
# if (!pageViewItem) {
# 	pageViewItem = {val: 1}
# }
# var currentTime = new Date();
# var midnight = new Date();
# var pageViewCount = 1;
# midnight.setDate(midnight.getDate() + 1);
# midnight.setHours(0, 0, 0, 0);
# if (currentTime < pageViewItem.ttl) {
# 	pageViewCount = parseInt(pageViewItem.val ?? 0) + 1;
# }
# window.adInfo = window.adInfo || {};
# window.adInfo.pgview = pageViewCount.toString();
# window.localStorage.setItem(awPageViewName, JSON.stringify({
# 	val: pageViewCount,
# 	ttl: Date.now() + Math.abs(midnight.getTime() - currentTime.getTime())
# }));
#
# var adPageInfo = {category:'weather',template:'extended'};
# var partnerCode = 'google_search_accuweather';
# var countryCode = 'uz';
# var networkType = 'mobile';
# var throughput = 'vhigh';
# </script>
# <script>
# 		var serverAdsOnPageLite = {"top":{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":12729470,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20260118"],"advelvet":["1"],"pgview":["1"],"partner":["google_search_accuweather"],"ufdb":["UZ25"],"country":["UZ"],"state":["QA"],"wx_seg":["102103100","102101100","100108101","101100100","102102100","102100100","108102100","102104102","101106102","101102102","100106105","101107101","108101100","104101101","100106104","107100100","108103102","101105101","107101100","100000100","101101100","100100","109101101","108104100","110100101","101104100","101108100","103100101","109105102","108100101","101103100","100113102","104100104","105100101","100109101","109100101","107103101","109106101","109102101","103101102","109103101","109104101","100114105","100109106"],"cuhd":["81"],"cuhi":["36"],"cuuv":["1"],"cuwd":["5"],"cuwx":["7"],"realfeel":["35","a40","b40","c45","d45"],"fc1hi":["40"],"fc1lo":["29"],"fc1wx":["7"],"lfscategory":["snow"],"lfsday":["5"],"lfsseverity":["4"],"lfs":["4_snow_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/extended"]},"reserve":0.02,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":640474,"position":"atf","userId":"71449b82e6b04b8f856b12afef81dc42","floor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"criteo","params":{"networkId":12212,"pubid":"3852","uid":"472391","bidFloor":0.02,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"38.88","lon":"65.8","kadfloor":"0.02","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"197759","bidFloor":0.02,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20260118"],"advelvet":["1"],"pgview":["1"],"partner":["google_search_accuweather"],"ufdb":["UZ25"],"country":["UZ"],"state":["QA"],"wx_seg":["102103100","102101100","100108101","101100100","102102100","102100100","108102100","102104102","101106102","101102102","100106105","101107101","108101100","104101101","100106104","107100100","108103102","101105101","107101100","100000100","101101100","100100","109101101","108104100","110100101","101104100","101108100","103100101","109105102","108100101","101103100","100113102","104100104","105100101","100109101","109100101","107103101","109106101","109102101","103101102","109103101","109104101","100114105","100109106"],"cuhd":["81"],"cuhi":["36"],"cuuv":["1"],"cuwd":["5"],"cuwx":["7"],"realfeel":["35","a40","b40","c45","d45"],"fc1hi":["40"],"fc1lo":["29"],"fc1wx":["7"],"lfscategory":["snow"],"lfsday":["5"],"lfsseverity":["4"],"lfs":["4_snow_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/extended"]},"customFloor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ttd","params":{"supplySourceId":"accuweather","publisherId":"1","bidfloor":0.02,"currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false}]},"adType":"top","viewport":"tablet desktop","adDivId":"top","adUnitCode":"/6581/web/asi/top/weather/extended","upr":0.05,"includeInSRA":true},"oop":{"co ...
# 		var USPString = '1YNN';
#
# 		try {
# 			;
# 		} catch (error) { }
#
# 		// A map object that stores all ads on page in order where key is the div id and value is the ad object
# 		var pageHasRepeatAds = false;
# 		var adsOnPage = new Map();
# 		const order = ["top","top_right","infeed","bottom_right","middle","native","bottom","oop","interstitial"];
# 		const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 			.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 			.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 		orderedAds.forEach((adId) => {
# 			const adObject = window.serverAdsOnPageLite[adId];
# 			adObject.winner = { auction: 0 };
# 			const strippedId = adId.split('-')[0];
# 			// Mark repeating ad units
# 			if (adsOnPage.has(strippedId)) {
# 				adObject.isRepeat = true;
# 				window.serverAdsOnPageLite[strippedId].isRepeat = true;
# 				window.pageHasRepeatAds = true;
# 			}
#
# 			// Get sizes from ad engine
# 			adObject.sizes = adObject.config.bids
# 				.find((b) => b.bidder === 'google')
# 				?.params?.sizes.split(',')
# 				.map((s) => (s.includes('x') ? s.split('x').map(Number) : s));
#
# 			adsOnPage.set(adId, adObject)
# 		});
#
# 		// Parse lazy loading config
# 		if (window.globalAdConfig?.lazyLoadingData) {
# 			let lazyLoadData;
# 			try {
# 				lazyLoadData = JSON.parse(window.globalAdConfig.lazyLoadingData.replace(/(['"])?([a-z0-9A-Z_]+)(['"])?:/g, '"$2": '));
# 			} catch (error) { }
# 			if (typeof lazyLoadData === 'object' && Object.keys(lazyLoadData).length > 0) {
# 				window.globalAdConfig.lazyLoadingData = lazyLoadData;
# 			} else {
# 				window.globalAdConfig.lazyLoadingData = null;
# 			}
# 		}
# 		window.adTimeline = [];
# 		window.logAdEvent = (event) => {
# 			window.adTimeline.push([performance.now().toFixed(2), event]);
# 		};
# 		document.addEventListener('DOMContentLoaded',() => {
# 			window.logAdEvent('DOM Ready');
# 		});
# 		function onDomReady(callback) {
# 			if (document.readyState === 'loading') {
# 				document.addEventListener('DOMContentLoaded', callback);
# 			} else {
# 				callback();
# 			}
# 		}
# 	</script>
# <script>
# 	var gaAppConfig = {
#   "snowfallMap": true,
#   "mapCta": true,
#   "iceChart": true,
#   "winterOutlookCard": true,
#   "winterUpcomingCard": true,
#   "impactedCities": true,
#   "tempWindChart": true,
#   "snowfallChart": true,
#   "postEventCta": true,
#   "winterCenterMap": true
# };
# 	var userCookie = {"cDate":"2026-01-18","isDarkMapStyle":false,"lang":"uz","rl":["350541"],"tp":"C","ccb":true,"userContentAffinity":{}};
# 	var recentLocations = [{"adminArea":{"englishName":"Kashkadarya","id":"QA","localizedName":"Qashqadaryo"},"alertCount":0,"country":{"englishName":"Uzbekistan","id":"UZ","localizedName":"O‘zbekiston"},"icon":7,"key":"350541","localizedName":"Qarshi","postalCode":"","temp":"2°","realFeel":"2°","isDayTime":true}];
# 	var currentLocation = {"plumeLabsLink":"https://air.plumelabs.com/air-quality-in-qarshi-56pV","englishName":"Qarshi","gmtOffset":5.0,"hasAlerts":false,"hasForecastConfidence":true,"hasPollen":false,"hasMinuteCast":true,"hasFutureRadar":true,"lat":38.883,"lon":65.8,"region":{"englishName":"Asia","id":"ASI","localizedName":"Osiyo"},"timeZone":"UZT","timeZoneCode":"UZT","administrativeArea":{"englishName":"Kashkadarya","id":"QA","localizedName":"Qashqadaryo"},"country":{"englishName":"Uzbekistan","id":"UZ","localizedName":"O‘zbekiston"},"key":"350541","localizedName":"Qarshi","primaryPostalCode":"","source":"AccuWeather"};
# 	var serverAdsOnPage = [{"config":{"responsiveSizes":[{"window":[1024,0],"sizes":["fluid",[980,120],[980,90],[970,250],[970,90],[950,90],[930,180],[750,100],[750,300],[750,200],[728,90]]},{"window":[768,0],"sizes":["fluid",[728,90],[468,60],[320,50],[300,50]]},{"window":[0,0],"sizes":[[320,100],[320,50],[300,250],[300,100],[300,50],[250,360],[240,400]]}],"bids":[{"bidder":"google","params":{"sizes":"970x250,728x90,fluid","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"appnexus","params":{"placementId":12729470,"allowSmallerSizes":"FALSE","keywords":{"fdate":["20260118"],"advelvet":["1"],"pgview":["1"],"partner":["google_search_accuweather"],"ufdb":["UZ25"],"country":["UZ"],"state":["QA"],"wx_seg":["102103100","102101100","100108101","101100100","102102100","102100100","108102100","102104102","101106102","101102102","100106105","101107101","108101100","104101101","100106104","107100100","108103102","101105101","107101100","100000100","101101100","100100","109101101","108104100","110100101","101104100","101108100","103100101","109105102","108100101","101103100","100113102","104100104","105100101","100109101","109100101","107103101","109106101","109102101","103101102","109103101","109104101","100114105","100109106"],"cuhd":["81"],"cuhi":["36"],"cuuv":["1"],"cuwd":["5"],"cuwx":["7"],"realfeel":["35","a40","b40","c45","d45"],"fc1hi":["40"],"fc1lo":["29"],"fc1wx":["7"],"lfscategory":["snow"],"lfsday":["5"],"lfsseverity":["4"],"lfs":["4_snow_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/extended"]},"reserve":0.02,"position":"above","supplyType":"web","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"rubicon","params":{"accountId":12562,"siteId":135890,"zoneId":640474,"position":"atf","userId":"71449b82e6b04b8f856b12afef81dc42","floor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"triplelift","params":{"inventoryCode":"accuweather_d_top_leaderboard_pbjs","floor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"criteo","params":{"networkId":12212,"pubid":"3852","uid":"472391","bidFloor":0.02,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"pubmatic","params":{"publisherId":"34576","adSlot":"Web_Top","lat":"38.88","lon":"65.8","kadfloor":"0.02","currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"yahoossp","params":{"dcn":"8a9691d3017474551cc955a9acbd0027","pos":"web_hb_top_1","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ix","params":{"siteId":"197759","bidFloor":0.02,"bidFloorCur":"USD","Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"openx","params":{"delDomain":"accuweather-d.openx.net","unit":"539580665","customParams":{"fdate":["20260118"],"advelvet":["1"],"pgview":["1"],"partner":["google_search_accuweather"],"ufdb":["UZ25"],"country":["UZ"],"state":["QA"],"wx_seg":["102103100","102101100","100108101","101100100","102102100","102100100","108102100","102104102","101106102","101102102","100106105","101107101","108101100","104101101","100106104","107100100","108103102","101105101","107101100","100000100","101101100","100100","109101101","108104100","110100101","101104100","101108100","103100101","109105102","108100101","101103100","100113102","104100104","105100101","100109101","109100101","107103101","109106101","109102101","103101102","109103101","109104101","100114105","100109106"],"cuhd":["81"],"cuhi":["36"],"cuuv":["1"],"cuwd":["5"],"cuwx":["7"],"realfeel":["35","a40","b40","c45","d45"],"fc1hi":["40"],"fc1lo":["29"],"fc1wx":["7"],"lfscategory":["snow"],"lfsday":["5"],"lfsseverity":["4"],"lfs":["4_snow_5"],"pt":["0"],"adunit":["/6581/web/asi/top/weather/extended"]},"customFloor":0.02,"Is_Buy_It_Now":false},"isBuyItNow":false},{"bidder":"ttd","params":{"supplySourceId":"accuweather","publisherId":"1","bidfloor":0.02,"currency":"USD","Is_Buy_It_Now":false},"isBuyItNow":false}]},"adType":"top","viewport":"tablet desktop","adDivId":"top","adUnitCode":"/6581/web/asi/top/weather/extended","upr":0.05,"includeInSRA":true},{"config":{"bids":[{" ...
# 	var weatherEvents = [{"startTimeFormattedShort":"Wed 11 PM","endTimeFormattedShort":"Thu 7 AM","forecastAmount":1.02,"start":"2026-01-21T23:00:00","end":"2026-01-22T07:00:00","localStart":"2026-01-22T04:00:00+05:00","localEnd":"2026-01-22T12:00:00+05:00","eventType":3}];
# 	var userData = {"city":"TASHKENT","continent":1,"countryCode":"UZ","county":"","lat":41.32,"lon":69.25,"regionCode":"","throughput":"vhigh","bw":"5000","networkType":"mobile","network":"","zipCodes":[{"primary":""}],"device":{"browserVersion":"143"}};
# 	var isUserCountryEEA = false;
# 	var maplibre = { style: 'https://accutilerprod.z14.web.core.windows.net/Styles/accu-light-row.json' };
# 	var dts = { token: 'de13920f574d420984d3080b1fa6132b' };
# 	setTimeout(function () {
# 		var reg = new RegExp('(\\s|^)' + 'ads-not-loaded' + '(\\s|$)');
# 		if (document.body.hasAttribute('class')) {
# 			document.body.setAttribute('class', document.body.getAttribute('class').replace(reg, ' '));
# 		}
# 	}, 3000);
# </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
# 		window.googletag = window.googletag || { cmd: [] };
# 		window.pbjs = window.pbjs || {};
# 		pbjs.que = pbjs.que || [];
# 		// Initialize ad info
# 		adInfo['hour'] = new Date().getHours().toString();
# 		const width = document.documentElement.clientWidth;
# 		const height = document.documentElement.clientHeight;
# 		const round = x => Math.ceil(x / 10) * 10;
# 		adInfo['viewport'] = `${round(width)}x${round(height)}`;
# 		adInfo['site'] = width >= 768
# 			? (width >= 1024 ? 'desktop' : 'tablet')
# 			: 'mobile';
# 		// Helper function for uprTargeting
# 		window.uprTargeting = (gptSlot, adObject) => {
#
# 						const uprTargeting = {
# 							upr: adObject.upr,
# 						upr_0: 'no_bid',
# 						upr_auction: 'skipped',
# 						hb_bid_1st: 'no_bid',
# 						hb_bid_2nd: 'no_bid',
# 												};
# 								if (gptSlot) {
# 				Object.keys(uprTargeting).forEach((key) => {
# 					if (uprTargeting[key]) {
# 						gptSlot.setTargeting(key, String(uprTargeting[key]));
# 					}
# 				});
# 			}
# 			return uprTargeting;
# 		};
#
# 		// Setup Gamera
# 		if (window.userData.countryCode.toLowerCase() === 'us') {
# 			// this is temporary to ensure a seamless transtion from ad server to page. I'll look for this value in the ad server code and if true, not load the ad server code.
# 			window.gameraFromPage = true;
#
# 			let aw_page = '', aw_gam_code = '', aw_partner = '', aw_wx_seg = '';
# 			let ltv = 1;
#
# 			try {
# 				if (window.serverAdsOnPageLite) {
# 					aw_gam_code = Object.values(window.serverAdsOnPageLite)[0].adUnitCode;
# 				}
#
# 				aw_page = window.RaineV2?.pageView?.pageInfo?.group || '';
# 				aw_partner = window?.adInfo?.partner || 'accuweather';
# 				aw_wx_seg = window?.adInfo?.wx_seg || '';
# 				ltv = window.adInfo?.rdp === '1' ? 0 : 1;
# 			} catch (e) { }
#
# 			window.gamera = window.gamera || {};
# 			window.gamera.cmd = window.gamera.cmd || [];
# 			window.gamera.cmd.push(function () {
# 				//custom dimensions
# 				window.gamera.addDimensions({
# 					"aw_site": aw_gam_code.split('/')[2],
# 					"aw_wxGeo": aw_gam_code.split('/')[3],
# 					"aw_page": aw_page.replace('/', ''),
# 					"aw_partner": aw_partner,
# 					"aw_wx_seg": aw_wx_seg
# 				});
#
# 				//set 3 new key-values in the adInfo object from Gamera on-page data to be passed as page-level key-value pairs
# 				try {
# 					let ucpm = window?.gamera?.getOnPageSegments()?.filter((cpm) => /^user_cpm/.test(cpm)).join(",") || undefined;
# 					if (ucpm) {
# 						ucpm = (Math.round(parseFloat(ucpm.split("_").pop()) * 20) / 20).toFixed(2);
# 						window.adInfo.ucpm = ucpm;
# 					}
# 				} catch (e) { }
#
# 				try {
# 					window.adInfo.cohort = window?.gamera?.getOnPageSegments()?.filter((cpm) => !/^user_cpm/.test(cpm)).join(",") || window.adInfo.cohort || undefined;
# 					window.adInfo.iabatax = window?.gamera?.getPrebidSegments()?.user?.data[0]?.segment?.map(a => a.id).join(',') || window.adInfo.iabatax || undefined;
# 				} catch (e) { }
# 			});
#
# 			//add the Gamera tag
# 			const s = document.createElement("script");
# 			const el = document.getElementsByTagName("script")[0];
# 			s.setAttribute('id', '__gamera__');
# 			s.setAttribute('async', 'true');
# 			s.src = `https://metrics.rapidedge.io/gamera.js?domain=accuweather.com&ltv=${ltv}&tpcs=1`;
# 			el.parentNode.insertBefore(s, el);
# 		}
#
# 		// Configure LiveIntent
# 		const TREATMENT_RATE = 0.90;
# 		if (window.liModuleEnabled === undefined) {
# 			// To manage the control group selection externally, override the
# 			// true = treated group, false = control group.
# 			window.liModuleEnabled = Math.random() < TREATMENT_RATE;
# 			window.liTreatmentRate = TREATMENT_RATE;
# 		}
#
# 		const injectLiveIntentTag = () => {
# 			var e = document.createElement("script");
# 			e.type = "text/javascript";
# 			e.src = "https://b-code.liadm.com/b-020q.min.js";
# 			e.defer = e.async = !0;
# 			document.getElementsByTagName("head")[0].appendChild(e);
# 		}
#
# 	if (window.userData?.countryCode?.toLowerCase() === 'us') {
# 		if (typeof window.ketch === 'function') {
# 			window.ketch('on', 'consent', () => {
# 				injectLiveIntentTag();
# 			});
# 		} else {
# 			injectLiveIntentTag();
# 		}
# 	}
# 	</script>
# <script>
#
# 					window.prebidBidPromise = Promise.resolve();
# 					window.prebidTimeoutPromise = Promise.resolve();
# 					const buyItNowBids = [];
# 						// Ad results object
# 		const prevAdResults = JSON.parse(localStorage.getItem('adResults'));
# 		if (adInfo.pgview === '1' && prevAdResults) {
# 			prevAdResults.previousRatio = prevAdResults.filledAds / prevAdResults.possibleAds;
# 			prevAdResults.filledAds = 0;
# 			prevAdResults.possibleAds = 0;
# 		}
# 		window.adResults = prevAdResults || {};
#
# 		// Start ad process
# 		googletag.cmd.push(function () {
# 			window.logAdEvent('GPT: Init');
# 			if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 				googletag.pubads().disableInitialLoad();
# 			}
# 			googletag.pubads().enableAsyncRendering();
# 			if (!window.globalAdConfig || window.globalAdConfig.enableSingleRequest) {
# 				googletag.pubads().enableSingleRequest();
# 			}
# 			googletag.pubads().setCentering(true);
# 			googletag.pubads().setSafeFrameConfig({
# 				allowOverlayExpansion: false,
# 				allowPushExpansion: true,
# 				sandbox: true,
# 			});
# 			// Set page level targeting
# 			for (const [key, value] of Object.entries(adInfo)) {
# 				if (value) {
# 					googletag.pubads().setTargeting(key, value);
# 				}
# 			}
#
# 			// Set privacy settings (TODO: Utilize Ketch / Tag Engine)
# 			googletag.pubads().setTargeting('optout', 'false');
#
# 			// Set ppid targeting
# 			const ppid = '71449b82e6b04b8f856b12afef81dc42';
# 			if (ppid) {
# 				googletag.pubads().setPublisherProvidedId(ppid);
# 			}
#
# 			// Set location
# 			if (window.userData && window.userData.zipCodes && window.userData.zipCodes.length > 0 && window.userData.countryCode.toLowerCase() === 'us') {
# 				const zip = window.userData.zipCodes[0].primary;
# 				googletag.pubads().setLocation(`${zip},US`);
# 			}
#
# 			// Init ad server
# 			const FAILSAFE_TIMEOUT = (window.globalAdConfig && typeof window.globalAdConfig.awxTimeout === 'number') ? window.globalAdConfig.awxTimeout : 10000;
# 			let IS_ADSERVER_INIT = false;
# 			const initAdserver = () => {
# 				if (IS_ADSERVER_INIT) {
# 					return;
# 				}
# 				IS_ADSERVER_INIT = true;
# 				window.logAdEvent('Init Ad Server');
# 				// Define ads in order
# 				const order = ["top","top_right","infeed","bottom_right","middle","native","bottom","oop","interstitial"];
# 				const orderedAds = Object.keys(window.serverAdsOnPageLite)
# 					.sort((a, b) => order.indexOf(a.split('-')[0]) - order.indexOf(b.split('-')[0]))
# 					.filter((adDivId) => order.indexOf(adDivId.split('-')[0]) > -1);
# 				const gptSlots = orderedAds.map((adDivId) => {
# 					const adsOnPage = window.serverAdsOnPageLite || {};
# 					const adObject = adsOnPage[adDivId];
# 					window.logAdEvent(`GPT: Create GPTSlot: ${adObject?.adDivId}. DOM exist: ${!!document.getElementById(adObject.adDivId)}`);
# 					if (adObject && document.getElementById(adObject.adDivId)) {
# 						// Check if buy it now bids won
# 						let highestBid = { cpm: 0 };
# 						if (pbjs?.getBidResponsesForAdUnitCode) {
# 							const bidResponses = pbjs.getBidResponsesForAdUnitCode(adObject.adUnitCode);
# 							// Get the BuyItNow bid with highest cpm
# 							bidResponses.bids.forEach((bid) => {
# 								if (buyItNowBids.indexOf(bid.requestId) > -1 && bid.cpm > highestBid.cpm) {
# 									highestBid = bid;
# 								}
# 							});
# 						}
# 						// If BuyItNow is valid, change the ad unit code geo part to bin_prebid
# 						//  - then if skipGoogleAdManager is true, render the creative and create an oop ad unit for DFP tracking
# 						//  - else, return the gptSlot with the new ad code
# 						// otherwise return the gptSlot with the original ad code
# 						let isAdUnitPartOfInitialAuction = true;
# 						if (window.globalAdConfig?.lazyLoadingData && window.pageHasRepeatAds && window.initialAdDivIdsAuction) {
# 							isAdUnitPartOfInitialAuction = window.initialAdDivIdsAuction.includes(adObject.adDivId);
# 						}
# 						if (highestBid.cpm > 0 && isAdUnitPartOfInitialAuction) {
# 							const adCode = adObject.adUnitCode.split('/');
# 							adCode[3] = 'bin_prebid';
# 							adObject.code = adCode.join('/');
# 							// Sets the pug page-level targeting
# 							googletag.pubads().setTargeting('pug', '1');
# 							if (!window.globalAdConfig || window.globalAdConfig.skipGoogleAdManager) {
# 								// Mark winner.auction 1 if a buy it now bid wins
# 								adObject.winner.auction = 1;
#
# 								window.renderPrebidWithIframe(adObject, highestBid);
# 								// Create the bin_prebid tracking slot
# 								const oopId = `${adObject.adDivId}-oop`;
# 								const oopDiv = document.createElement('div');
# 								oopDiv.setAttribute('id', oopId);
# 								oopDiv.setAttribute('class', 'tracking-slot');
# 								document.body.appendChild(oopDiv);
# 								const gptSlot = googletag.defineOutOfPageSlot(adObject.code, oopId);
# 								gptSlot?.addService(googletag.pubads());
# 								Object.keys(highestBid.adserverTargeting).forEach((key) => {
# 									gptSlot.setTargeting(key, highestBid.adserverTargeting[key]);
# 								});
# 								if (window.adInfo) {
# 									if (window.adInfo.partner) {
# 										gptSlot.setTargeting('partner', window.adInfo.partner);
# 									}
# 									gptSlot.setTargeting('userid3p', window.adInfo.userid3p);
# 								}
# 								adObject.gptSlot = gptSlot;
# 								return gptSlot;
# 							}
# 						}
#
# 						let gptSlot;
# 						if (adObject.adType === 'oop') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, adObject.adDivId);
# 						} else if (adObject.adType === 'interstitial') {
# 							gptSlot = googletag.defineOutOfPageSlot(adObject.adUnitCode, googletag.enums.OutOfPageFormat.INTERSTITIAL);
# 						} else {
# 							gptSlot = googletag.defineSlot(adObject.adUnitCode, adObject.sizes, adObject.adDivId);
# 						}
#
# 						window.uprTargeting(gptSlot, adObject);
#
# 						// Set ad div min height
# 						let maxHeight = 0;
# 						adObject.sizes.forEach((size) => {
# 							if (Array.isArray(size) && size[1] > maxHeight) {
# 								maxHeight = size[1];
# 							}
# 						});
# 						const adDiv = document.getElementById(adObject.adDivId);
# 						if (adDiv && maxHeight > 0) {
# 							adDiv.style.minHeight = `${maxHeight}px`;
# 						}
#
# 						// Set Gamera targeting
# 						try {
# 							window.gamera._getAdPlacements().forEach(({ divId, universalPlacementId }) => {
# 								if (divId === adObject.adDivId && universalPlacementId) {
# 									gptSlot.setTargeting('upid', universalPlacementId);
# 								}
# 							});
# 						} catch (e) { }
#
# 						gptSlot?.addService(googletag.pubads());
# 						adObject.gptSlot = gptSlot;
# 						// Only return the gptSlot that's included in initial request
# 						if (adObject.includeInSRA) {
# 							return gptSlot;
# 						}
# 					}
# 					return null;
# 				}).filter((x) => x);
# 				if (window.globalAdConfig?.lazyLoadingData) {
# 					googletag.pubads().enableLazyLoad(window.globalAdConfig.lazyLoadingData);
# 				}
# 				// Enable services when all slots are defined
# 				googletag.enableServices();
# 				// Call display after services are enabled
# 				gptSlots.forEach((gptSlot) => {
# 					const adDivId = gptSlot.getSlotElementId();
# 					window.logAdEvent(`GPT: Display: ${adDivId}`);
# 					googletag.display(adDivId);
# 				});
# 				// Renders all ads on page
# 				window.logAdEvent(`Prebid: setTargetingForGPTAsync`);
# 				window.pbjs?.setTargetingForGPTAsync && pbjs.setTargetingForGPTAsync();
# 				if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 					window.logAdEvent(`GPT: Refresh`);
# 					if (window.globalAdConfig && !window.globalAdConfig.enableSingleRequest) {
# 						gptSlots.forEach((gptSlot) => {
# 							googletag.pubads().refresh([gptSlot]);
# 						});
# 					} else {
# 						googletag.pubads().refresh(gptSlots);
# 					}
# 				}
# 			};
#
# 			// If initial ad load is disabled, wait for prebid
# 			onDomReady(() => {
# 				if (!window.globalAdConfig || window.globalAdConfig.disableInitialAdLoad) {
# 					setTimeout(() => {
# 						window.logAdEvent(`initAdServer Failsafe Timeout`);
# 						initAdserver();
# 					}, FAILSAFE_TIMEOUT);
# 					window.prebidBidPromise.then(initAdserver);
# 				} else {
# 					initAdserver();
# 				}
# 			});
# 			googletag.pubads().addEventListener('slotRenderEnded', (event) => {
# 				if (document.body.classList.contains('ads-not-loaded')) {
# 					setTimeout(() => document.body.classList.remove('ads-not-loaded'), 750);
# 				}
# 				const adSlot = window.serverAdsOnPageLite[event.slot.getSlotElementId()];
# 				if (adSlot) {
# 					const renderedAdEl = document.getElementById(adSlot.adDivId);
# 					if (renderedAdEl) {
# 						setTimeout(() => {
# 							renderedAdEl.classList.remove('unrendered');
# 						}, 250);
# 					}
# 				}
# 			});
# 			let isInterstitialRendered = false;
# 			googletag.pubads().addEventListener('slotResponseReceived', () => {
# 				if (window.isLoginPopupOpen) {
# 					return;
# 				}
#
# 				if (!isInterstitialRendered && window.serverAdsOnPageLite['interstitial']) {
# 					isInterstitialRendered = true;
# 					const { gptSlot } = window.serverAdsOnPageLite['interstitial'];
# 					if (gptSlot) {
# 						googletag.display(gptSlot.getSlotElementId());
# 						googletag.pubads().refresh([gptSlot]);
# 					}
# 				}
# 			});
# 		});
# 	</script>
# <script>
# function getAwxSession(categories, pageId) {
# 	const AWX_SESSION_NAME = 'awx_session';
# 	const defaultVal = {
# 		categoryFlow: [],
# 		visitFlow: [],
# 		ttl: Date.now() + 600000
# 	};
#
# 	let awxSession = JSON.parse(window.localStorage.getItem(AWX_SESSION_NAME) || '{}');
# ...
# <p class="panel-item">RealFeel Shade™<span class="value">10°</span></p>
# </div>
# <div class="right">
# <p class="panel-item">Maks. UB indeksi<span class="value">1.0 (Yaxshi)</span></p>
# <p class="panel-item">Shamol<span class="value">WNW 9 km/soat</span></p>
# </div>
# </div>
# </div>
# </div>
# <div class="glacier-ad unrendered middle config-middle content-module" data-ad-type="middle" data-viewport="" id="middle-5"></div>
# <div class="daily-wrapper" data-qa="dailyCard28">
# <a class="daily-forecast-card" href="/uz/uz/qarshi/350541/daily-weather-forecast/350541?day=29">
# <div class="info">
# <h2 class="date">
# <span class="module-header dow date">Yak</span>
# <span class="module-header sub date">15/02</span>
# </h2>
# <svg class="icon" data-src="/images/weathericons/6.svg" height="128" viewbox="0 0 288 288" width="128"><g fill="none" fill-rule="evenodd" stroke-width="9.778"><path d="M100 49v34.222M46.222 136.658H12M61.916 98.573l-24.2-24.2M128.209 109.427a39.111 39.111 0 1 0-53.778 56.71" stroke="#FF8700"></path><path d="M276 183.102a56.222 56.222 0 0 0-56.222-56.222h-9.534c-17.963-21.15-46.919-29.36-73.31-20.788-26.391 8.572-44.996 32.23-47.103 59.9H78.05c-20.25 0-36.667 16.415-36.667 36.666 0 20.25 16.416 36.666 36.667 36.666h141.778c31.031-.027 56.173-25.19 56.173-56.222Z" stroke="#BABABA"></path></g></svg>
# <div class="temp">
# <span class="high">8°</span>
# <span class="low">/-1°</span>
# </div>
# </div>
# <div class="precip">
# <svg class="precip-icon" viewbox="0 0 12 16" xmlns="http://www.w3.org/2000/svg"><path d="M5.532.891c1.723.952 5.315 5.477 5.775 8.756.028 1.718-.534 3.101-1.45 4.082C8.888 14.766 7.52 15.357 6 15.357a5.532 5.532 0 0 1-3.74-1.425c-.975-.89-1.587-2.124-1.616-3.49.503-4.035 4.013-8.49 4.888-9.551Zm-1.815 7.33a.336.336 0 0 0-.025.043c-.322.62-.59 1.255-.695 2.207.012.408.143.787.358 1.111.234.352.568.641.96.839.035.017.071.021.106.017a.201.201 0 0 0 .104-.044l.01-.005-.078-.1c-.328-.415-.82-1.067-.82-1.946 0-.752.076-1.613.08-2.121Z" fill="none" fill-rule="nonzero" stroke="#878787" stroke-width=".714"></path></svg>
# 		25%
# 	</div>
# <svg class="cta-arrow" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <div class="half-day-card-content">
# <div class="phrase">Havo serbulut</div>
# <div class="panels">
# <div class="left">
# <p class="panel-item">RealFeel®<span class="value">11°</span></p>
# <p class="panel-item">RealFeel Shade™<span class="value">9°</span></p>
# </div>
# <div class="right">
# <p class="panel-item">Maks. UB indeksi<span class="value">2.0 (Yaxshi)</span></p>
# <p class="panel-item">Shamol<span class="value">WSW 4 km/soat</span></p>
# </div>
# </div>
# </div>
# </div>
# <div class="daily-wrapper" data-qa="dailyCard29">
# <a class="daily-forecast-card" href="/uz/uz/qarshi/350541/daily-weather-forecast/350541?day=30">
# <div class="info">
# <h2 class="date">
# <span class="module-header dow date">Dush</span>
# <span class="module-header sub date">16/02</span>
# </h2>
# <svg class="icon" data-src="/images/weathericons/1.svg" height="128" viewbox="0 0 288 288" width="128"><g fill="none" fill-rule="evenodd" stroke="#FF8700" stroke-width="9.6"><path d="M144 0v48M144 240v48M0 144h48M211.872 76.128l33.936-33.936M245.808 245.808l-33.936-33.936M76.128 76.128 42.192 42.192"></path><circle cx="144" cy="144" r="76.8"></circle><path d="m76.128 211.872-33.936 33.936M240 144h48"></path></g></svg>
# <div class="temp">
# <span class="high">7°</span>
# <span class="low">/-1°</span>
# </div>
# </div>
# <div class="precip">
# <svg class="precip-icon" viewbox="0 0 12 16" xmlns="http://www.w3.org/2000/svg"><path d="M5.532.891c1.723.952 5.315 5.477 5.775 8.756.028 1.718-.534 3.101-1.45 4.082C8.888 14.766 7.52 15.357 6 15.357a5.532 5.532 0 0 1-3.74-1.425c-.975-.89-1.587-2.124-1.616-3.49.503-4.035 4.013-8.49 4.888-9.551Zm-1.815 7.33a.336.336 0 0 0-.025.043c-.322.62-.59 1.255-.695 2.207.012.408.143.787.358 1.111.234.352.568.641.96.839.035.017.071.021.106.017a.201.201 0 0 0 .104-.044l.01-.005-.078-.1c-.328-.415-.82-1.067-.82-1.946 0-.752.076-1.613.08-2.121Z" fill="none" fill-rule="nonzero" stroke="#878787" stroke-width=".714"></path></svg>
# 		5%
# 	</div>
# <svg class="cta-arrow" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <div class="half-day-card-content">
# <div class="phrase">Quyoshli</div>
# <div class="panels">
# <div class="left">
# <p class="panel-item">RealFeel®<span class="value">10°</span></p>
# <p class="panel-item">RealFeel Shade™<span class="value">6°</span></p>
# </div>
# <div class="right">
# <p class="panel-item">Maks. UB indeksi<span class="value">4.0 (Oʻrtacha)</span></p>
# <p class="panel-item">Shamol<span class="value">NE 7 km/soat</span></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="more-cta-links">
# <h2 class="more-cta-title">
# </h2><p>Dunyo boʻylab</p>
# <a class="cta-link" data-ga-page-id="hurricane_tracker" data-page-id="hurricane" href="/uz/hurricane">
# <h3 class="cta-text">To‘fon</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="radar_and_maps" data-page-id="map-radar" href="/uz/uz/kashkadarya/weather-radar">
# <h3 class="cta-text">Radar va xaritalar</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# <a class="cta-link" data-ga-page-id="video" data-page-id="video-wall" href="/uz/videos">
# <h3 class="cta-text">Video</h3>
# <svg class="icon-arrow" height="18" viewbox="0 0 18 18" width="18" xmlns="http://www.w3.org/2000/svg"><defs><path d="m8.495.505 5 5v.99l-5 5-.99-.99 3.805-3.806L0 6.7V5.3l11.31-.001-3.805-3.804.99-.99z" id="a"></path></defs><use fill="#000" fill-rule="nonzero" transform="translate(2 3)" xlink:href="#a"></use></svg>
# </a>
# </div>
# </div>
# <div class="page-column-2">
# <div class="right-rail left-align-children">
# <div class="glacier-ad unrendered top_right config-top_right content-module" data-ad-type="top_right" data-viewport="tablet desktop" id="top_right"></div>
# <div class="glacier-ad unrendered bottom_right config-bottom_right content-module" data-ad-type="bottom_right" data-viewport="tablet desktop" id="bottom_right"></div>
# </div>
# </div>
# </div>
# <div class="glacier-ad unrendered bottom config-bottom content-module" data-ad-type="bottom" data-viewport="" id="bottom"></div>
# <div class="breadcrumbs">
# <div class="crumbs">
# <a class="breadcrumbs__link" href="/uz/world-weather">Dunyo</a>
# <svg class="breadcrumbs__chevron chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# <a class="breadcrumbs__link" href="/uz/asia-weather">Osiyo</a>
# <svg class="breadcrumbs__chevron chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# <a class="breadcrumbs__link" href="/uz/uz/uzbekistan-weather">O‘zbekiston</a>
# <svg class="breadcrumbs__chevron chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# <a class="breadcrumbs__link" href="/uz/uz/qa/kashkadarya-weather">Qashqadaryo</a>
# <svg class="breadcrumbs__chevron chevron-icon right" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M10 .969L9.037 0 5 4.063.963 0 0 .969 5 6z"></path></svg>
# <a class="breadcrumbs__link" href="/uz/uz/qarshi/350541/weather-forecast/350541">Qarshi</a>
# </div>
# </div>
# <div class="neighbors-wrapper">
# <div class="neighbors-wrapper__content">
# <h2 class="neighbors-title">Yaqin atrofdagi joylar:</h2>
# <div class="neighbors-scroll">
# <ul class="neighbor-items" id="neighbors">
# <li class="neighbor-item" itemprop="address" itemscope="true" itemtype="https://schema.org/PostalAddress">
# <a class="neighbor-link" data-from-string="nearby_locations" href="/uz/uz/beshkent/355640/weather-forecast/355640">
# <span itemprop="addressLocality">Beshkent</span>,
# 							<span itemprop="addressRegion">Qashqadaryo</span>
# </a>
# </li>
# <li class="neighbor-item" itemprop="address" itemscope="true" itemtype="https://schema.org/PostalAddress">
# <a class="neighbor-link" data-from-string="nearby_locations" href="/uz/uz/maymanak/355662/weather-forecast/355662">
# <span itemprop="addressLocality">Maymanak</span>,
# 							<span itemprop="addressRegion">Qashqadaryo</span>
# </a>
# </li>
# <li class="neighbor-item" itemprop="address" itemscope="true" itemtype="https://schema.org/PostalAddress">
# <a class="neighbor-link" data-from-string="nearby_locations" href="/uz/uz/nurobod/719969/weather-forecast/719969">
# <span itemprop="addressLocality">Nurobod</span>,
# 							<span itemprop="addressRegion">Samarqand</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="base-footer">
# <span class="">
# </span>
# <div class="footer-legalese">
# <div class="footer-copyright">
# <span>
# 			© 2026 AccuWeather, Inc. “AccuWeather” va “Sun design” AccuWeather, Inc. kompaniyasining roʻyxatga olingan savdo belgilaridir. Barcha huquqlar himoyalangan.
#
# 		</span>
# </div>
# <div class="footer-terms" id="footer-terms">
# <a data-ga="Terms of Use" href="/uz/legal" target="_blank">
# 			Foyd-sh shartlari
# 		</a>
# 		|
# 		<a data-ga="Privacy Policy" href="/uz/privacy" target="_blank">
# 			Maxfiylik siyosati
# 		</a>
# 		|
# 		<a data-ga="Cookie Policy" href="/uz/cookiepolicy" target="_blank">
# 			Cookie-fayllar siyosati
# 		</a>
# 		|
# 		<a data-ga="Data Sources" href="/uz/data-sources" target="_blank">
# 			Maʼlumot manbalari
# 		</a>
# </div>
# </div>
# </div>
# </div>
# <script>
# 		// Check for third party cookie support
# 		const thirdPartyIframe = document.createElement('iframe');
# 		thirdPartyIframe.setAttribute(
# 			'src',
# 			'https://www.awxcdn.com/adc/3rdpartycheck.html'
# 		);
# 		thirdPartyIframe.setAttribute('style', 'width:0;height:0;display:none');
# 		document.body.appendChild(thirdPartyIframe);
# 	</script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/city.daily-desktop.d112fd3f5e0ebc6d9103.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/6122.eb9e7a5bb86c761b6ebc.js"></script>
# <script async="" charset="utf-8" src="https://www.awxcdn.com/adc-assets/bundles/legacy-header.5c2e661633daf1f01e68.js"></script>
# <script>
# 		window.tagEngineDataLayer = window.tagEngineDataLayer || {};
# 		window.tagEngineDataLayer.connatix = {"isActive":true,"adUnitCode":"/6581/web/asi/video_player/weather/extended","adInfo":{"fdate":"20260118","lang":"uz","ut":"1","advelvet":"1","bot":"1, Unknown Bot (DCDF55702DF6A948E951CDBF9EA3D01D):monitor:Browser Impersonator","pgview":"1","partner":"google_search_accuweather","ufdb":"UZ25","city":"Qarshi","country":"UZ","state":"QA","dma":null,"key":"350541","browser":"chrome","connection":"mobile_vhigh_5000","wx_seg":"102103100,102101100,100108101,101100100,102102100,102100100,108102100,102104102,101106102,101102102,100106105,101107101,108101100,104101101,100106104,107100100,108103102,101105101,107101100,100000100,101101100,100100,109101101,108104100,110100101,101104100,101108100,103100101,109105102,108100101,101103100,100113102,104100104,105100101,100109101,109100101,107103101,109106101,109102101,103101102,109103101,109104101,100114105,100109106","cuhd":"81","cuhi":"36","cuuv":"1","cuwd":"5","cuwx":"7","realfeel":"35,a40,b40,c45,d45","fc1hi":"40","fc1lo":"29","fc1wx":"7","lfscategory":"snow","lfsday":"5","lfsseverity":"4","lfs":"4_snow_5","pt":"0","userid":"active","userid3p":"active","iabctax":"IAB15-10,390,657","sub":"free"},"ppid":"71449b82e6b04b8f856b12afef81dc42","thirdPartyCookie":"active","cacheBuster":639043158698209907,"gdprConsent":null};
# 	</script>
# <script>
#         window.tagEngineDataLayer = window.tagEngineDataLayer || {};
#         window.tagEngineDataLayer.comScore = {
#             cs_fpid: "71449b82-e6b0-4b8f-856b-12afef81dc42",
#             c4: "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541",
#             c7: "https://www.accuweather.com/uz/uz/qarshi/350541/daily-weather-forecast/350541",
#             c8: "Qarshi, Qashqadaryo, O&#x2018;zbekiston Kunlik ob-havo | AccuWeather",
#             c9: "https://www.google.com/"
#         };
#     </script>
# <script>
# 	var isPushlyEnabled = false;
# </script>
# <script>
# 		function callBlockthroughScript() {
# 			const scriptEl = document.getElementById('bt_bootstrap_2.0')
# 			if (!scriptEl) {
# 				const s = document.createElement("script");
# 				el = document.getElementsByTagName("script")[0];
# 				s.setAttribute('id', 'bt_bootstrap_2.0');
# 				s.async = true;
# 				s.src = "//accuweather-com.videoplayerhub.com/btTag.js?w=5760049299324928";
# 				el.parentNode.insertBefore(s, el);
# 			}
# 		};
#
# 			if (typeof window.ketch === 'function') {
# 				window.ketch('on', 'consent', () => {
# 					window.addEventListener('load', callBlockthroughScript);
# 					setTimeout(callBlockthroughScript, 15000);
# 				});
# 			} else {
# 				window.addEventListener('load', callBlockthroughScript);
# 				setTimeout(callBlockthroughScript, 15000);
# 			}
# 				</script>
# <script>
# 		try {
# 		;
# 		} catch (error) { }
# 	</script>
# <script>(async () => {(function(){function m(n,e){const c="https://sb.scorecardresearch.com/p?",t=Array.from(document.querySelectorAll('img[src^="'+c+'"]'));if(t.find(s=>s.src.includes(`cs_ucfr=${n}`)))return;const o=t.find(s=>s.src.includes("cs_ucfr=")&&!s.src.includes(`cs_ucfr=${n}`));o&&o.remove();const d=`${c}cs_fpid=${e.cs_fpid}&cs_fpit=c&c1=2&c2=6005068&c4=${encodeURIComponent(e.c4)}&c7=${encodeURIComponent(e.c7)}&c8=${encodeURIComponent(e.c8)}&c9=${encodeURIComponent(e.c9)}&cs_ucfr=${n}`,i=document.createElement("img");i.src=d,i.alt="ComScore",i.style.display="none",document.body.appendChild(i)}function a(){const n=window.tagEngineDataLayer?.comScore;if(!n)return;const e=100,c=2e3;let t=0;const r=()=>{typeof window.ketch=="function"?window.ketch("on","consent",function(o){const d=o?.purposes?.targeted_advertising;m(d===!0?1:0,n)}):t<c&&(t+=e,setTimeout(r,e))};r()}document.readyState==="complete"||document.readyState==="interactive"?a():document.addEventListener("DOMContentLoaded",a)})();
# //# sourceMappingURL=comscore.inline.5-abc6ca40.js.map
# })();</script><script>(async () => {(function(){const r=window.tagEngineDataLayer?.connatix;if(!r||!r.isActive)return;const{adUnitCode:i,cacheBuster:d,ppid:p,gdprConsent:e,adInfo:c,thirdPartyCookie:m}=r,t=new URL("https://securepubads.g.doubleclick.net/gampad/adx");if(t.searchParams.set("iu",i),t.searchParams.set("sz","3x3"),t.searchParams.set("c",d),t.searchParams.set("m","text/javascript"),t.searchParams.set("ppid",p),t.searchParams.set("userid3p",m||h()),c&&typeof c=="object"){const s=Object.entries(c).map(([o,a])=>`${o}=${a}`).join("&");s&&t.searchParams.set("t",encodeURIComponent(s))}typeof e=="string"&&e.trim()!==""&&e!=="0"&&(t.searchParams.set("gdpr","1"),t.searchParams.set("gdpr_consent",e));const n=document.createElement("script");n.src=t.toString(),n.async=!0,document.head.appendChild(n);function h(){const s="userid3p",a=document.cookie.split("; ").find(u=>u.startsWith(s+"="));return a?a.split("=")[1]:""}})();
# //# sourceMappingURL=connatix.inline.25-3b867b16.js.map
# })();</script>
# </body>
# </html>
