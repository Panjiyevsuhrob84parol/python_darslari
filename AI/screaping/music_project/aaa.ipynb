# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.last.fm/charts"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

songs = []

rows = soup.select("tr.chartlist-row")

for row in rows:
    rank = row.select_one("td.chartlist-position").text.strip()
    song = row.select_one("td.chartlist-name a").text.strip()
    artist = row.select_one("td.chartlist-artist a").text.strip()
    listeners = row.select_one("td.chartlist-listeners").text.strip()

    songs.append({
        "Rank": int(rank),
        "Song": song,
        "Artist": artist,
        "Listeners": listeners.replace(",", "")
    })

df = pd.DataFrame(songs)

print(df.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
