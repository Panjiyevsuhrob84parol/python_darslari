# %%
import pandas as pd
df_titanic = pd.read_csv("./Titanic_Dataset.csv")
df_titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df_titanic.drop(["name", "embarked", "body" ,"ticket", "cabin"], axis=1).head()
# df_titanic.columns
# Out:
#    pclass  survived     sex    age  sibsp  parch      fare boat  \
# 0       1         1  female  29.00      0      0  211.3375    2
# 1       1         1    male   0.92      1      2  151.5500   11
# 2       1         0  female   2.00      1      2  151.5500  NaN
# 3       1         0    male  30.00      1      2  151.5500  NaN
# 4       1         0  female  25.00      1      2  151.5500  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df_titanic[["sex", "age"]].head()
# Out:
#       sex    age
# 0  female  29.00
# 1    male   0.92
# 2  female   2.00
# 3    male  30.00
# 4  female  25.00

# %%
df_titanic.loc[[3,4,8], ["sex", "age"]]
# Out:
#       sex   age
# 3    male  30.0
# 4  female  25.0
# 8  female  53.0

# %%
df_titanic.iloc[5, 8]
# Out:
# np.float64(26.55)

# %%
df_titanic.loc[5, "sex"]
# Out:
# 'male'

# %%
df_titanic[df_titanic['age']>75]
# Out:
#     pclass  survived                                               name  \
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        sex   age  sibsp  parch ticket   fare cabin embarked boat  body  \
# 14    male  80.0      0      0  27042  30.00   A23        S    B   NaN
# 61  female  76.0      1      0  19877  78.85   C46        S    6   NaN
#
#                   home.dest
# 14            Hessle, Yorks
# 61  Little Onn Hall, Staffs

# %%
df_titanic["pclass"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64
