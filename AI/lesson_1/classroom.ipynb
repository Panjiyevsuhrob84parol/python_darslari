# %%
import numpy as np

b=np.zeros((2,3))
b[0,0]=10
b[0,1]=20
b[0,2]=30
b[1,0]=40
b[1,1]=50
b[1,2]=60

print(b)
# Out:
# [[10. 20. 30.]
#  [40. 50. 60.]]

# %%
import numpy as np

np.array([1, 2, 3])
# Out:
# ali

# %%
import pandas as pd 
df=pd.read_csv("./Titanic_Dataset.csv")
# df.head()        boshidagi malumotlar
# df.describe()     Sonli ustunlar statistikasi (o‘rtacha, min, max)
# df[df['survived'] == 1]       ### Faqat tirik qolganlar (erkak/ayol)
df[df['sex'] == 'female']    ###  Tirirk qolgan ayollar ayollar
# df[(df['survived'] == 1) & (df['sex'] == 'female')]       ### Tirik qolgan ayollar (ENG KO‘P ISHLATILADIGANI)
# df.groupby('pclass')['survived'].mean() * 100         ##### Klass bo‘yicha tirik qolish foizi
# df.groupby('sex')['survived'].sum()           ###### Jins buyicha tirik qolganlar soni
# df[df['survived'] == 1]['age'].mean()           ###### O‘rtacha yosh (tirik qolganlar)

# df.drop(
#     columns=['ticket', 'cabin', 'boat', 'body', 'home.dest'],
#     inplace=True
# )

# df.head()
# df.columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
